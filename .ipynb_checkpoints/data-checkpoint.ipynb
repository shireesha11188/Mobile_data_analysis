# %%
import pandas as pd
from sqlalchemy import create_engine

server="LAPTOP-91GGJ4MU"
database="MOBILE"
driver= "ODBC Driver 17 for SQL Server"

engine = create_engine(f"mssql+pyodbc://@{server}/{database}?trusted_connection=yes&driver={driver}")
df=pd.read_csv(r"C:\Users\HP\Desktop\excel files\mobile_usage.csv")

# %%
column_mapping={
    'Phone Brand':'Brand',
    'Number of Apps Installed': 'App Count',
    'Social Media Time (hrs/day)': 'Social Time',
    'Monthly Recharge Cost (INR)': 'Monthly Recharge',
    
}
df.rename(columns=column_mapping,inplace=True)

# %%
df.columns=df.columns.str.lower().str.replace(r"\s*\(.*?\)", "", regex=True)
df.columns = df.columns.str.replace(" ", "_")

# %%
df.index=df.index+1

# %%
df.to_sql("mobile_usage", engine, if_exists="replace", index=False)
# Out:
# 1

# %%
df
# Out:
#       user_id  age  gender   location    brand       os  screen_time  \
# 1      U00001   53    Male     Mumbai     Vivo  Android          3.7
# 2      U00002   60   Other      Delhi   Realme      iOS          9.2
# 3      U00003   37  Female  Ahmedabad    Nokia  Android          4.5
# 4      U00004   32    Male       Pune  Samsung  Android         11.0
# 5      U00005   16    Male     Mumbai   Xiaomi      iOS          2.2
# ...       ...  ...     ...        ...      ...      ...          ...
# 17682  U17682   27   Other     Mumbai    Apple      iOS          7.2
# 17683  U17683   40  Female    Chennai     Oppo      iOS          9.5
# 17684  U17684   34  Female  Ahmedabad   Realme  Android          1.1
# 17685  U17685   22    Male  Hyderabad     Vivo  Android          8.8
# 17686  U17686   43   Other    Kolkata     Oppo      iOS          5.6
#
#        data_usage  calls_duration  app_count  social_time  e-commerce_spend  \
# ...
